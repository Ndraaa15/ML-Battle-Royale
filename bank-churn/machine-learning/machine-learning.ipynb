# %%
import pandas as pd

# %%
df = pd.read_csv('../dataset/train.csv')
df.head()
# Out:
#    id  CustomerId         Surname  CreditScore Geography Gender   Age  Tenure  \
# 0   0    15674932  Okwudilichukwu          668    France   Male  33.0       3
# 1   1    15749177   Okwudiliolisa          627    France   Male  33.0       1
# 2   2    15694510           Hsueh          678    France   Male  40.0      10
# 3   3    15741417             Kao          581    France   Male  34.0       2
# 4   4    15766172       Chiemenam          716     Spain   Male  33.0       5
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              2        1.0             0.0        181449.97
# 1       0.00              2        1.0             1.0         49503.50
# 2       0.00              2        1.0             0.0        184866.69
# 3  148882.54              1        1.0             1.0         84560.88
# 4       0.00              2        1.0             1.0         15068.83
#
#    Exited
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.isnull().sum()
# Out:
# id                 0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df = df.drop(['id', 'CustomerId', 'Surname'], axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

columns = ['Geography', 'Gender'] 

for col in df[columns]:
    enc = label_encoder.fit(df[col])
    encoded = label_encoder.transform(df[col])
    df[col] = encoded
    print(enc.classes_)
    print(enc.transform(enc.classes_))
# Out:
# ['France' 'Germany' 'Spain']
# [0 1 2]
# ['Female' 'Male']
# [0 1]

# %%
X = df.drop('Exited', axis=1)
y = df['Exited']

# %%
# from sklearn.preprocessing import PowerTransformer

# scaler = PowerTransformer()
# X_scaled = scaler.fit_transform(X)
# X_scaled_df = pd.DataFrame(X_scaled, index=X.index, columns=X.columns)
# X_scaled_df.head()
# Out:
#    CreditScore  Geography    Gender       Age    Tenure   Balance  \
# 0     0.135077  -0.855127  0.878465 -0.512621 -0.671881 -0.916825
# 1    -0.376409  -0.855127  0.878465 -0.512621 -1.500119 -0.916825
# 2     0.260575  -0.855127  0.878465  0.353745  1.655948 -0.916825
# 3    -0.944170  -0.855127  0.878465 -0.375473 -1.068651  1.119941
# 4     0.740033   1.383661  0.878465 -0.512621  0.055708 -0.916825
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0       0.870578   0.571263        -0.99555         1.366240
# 1       0.870578   0.571263         1.00447        -1.253525
# 2       0.870578   0.571263        -0.99555         1.433748
# 3      -1.044538   0.571263         1.00447        -0.554259
# 4       0.870578   0.571263         1.00447        -1.945322

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled_df = pd.DataFrame(X_scaled, index=X.index, columns=X.columns)
X_scaled_df.head()
# Out:
#    CreditScore  Geography    Gender       Age    Tenure   Balance  \
# 0     0.144135  -0.794229  0.878465 -0.578074 -0.719973 -0.883163
# 1    -0.367706  -0.794229  0.878465 -0.578074 -1.432694 -0.883163
# 2     0.268974  -0.794229  0.878465  0.211354  1.774548 -0.883163
# 3    -0.941966  -0.794229  0.878465 -0.465299 -1.076334  1.486918
# 4     0.743362   1.655035  0.878465 -0.578074 -0.007253 -0.883163
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0       0.814298   0.571263        -0.99555         1.369486
# 1       0.814298   0.571263         1.00447        -1.254085
# 2       0.814298   0.571263        -0.99555         1.437422
# 3      -1.013348   0.571263         1.00447        -0.557018
# 4       0.814298   0.571263         1.00447        -1.938770

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(max_depth=7, random_state=0)
rfr.fit(X_scaled_df, y)
# Out:
# RandomForestRegressor(max_depth=7, random_state=0)

# %%
df_test = pd.read_csv('../dataset/test.csv') 
df_test.head()
# Out:
#        id  CustomerId    Surname  CreditScore Geography  Gender   Age  Tenure  \
# 0  165034    15773898   Lucchese          586    France  Female  23.0       2
# 1  165035    15782418       Nott          683    France  Female  46.0       2
# 2  165036    15807120         K?          656    France  Female  34.0       7
# 3  165037    15808905  O'Donnell          681    France    Male  36.0       8
# 4  165038    15607314    Higgins          752   Germany    Male  38.0      10
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0       0.00              2        0.0             1.0        160976.75
# 1       0.00              1        1.0             0.0         72549.27
# 2       0.00              2        1.0             0.0        138882.09
# 3       0.00              1        1.0             0.0        113931.57
# 4  121263.62              1        1.0             0.0        139431.00

# %%
id = df_test['id']
df_test = df_test.drop(['id', 'CustomerId', 'Surname'], axis=1)

# %%
columns = ['Geography', 'Gender'] 

for col in df_test[columns]:
    enc = label_encoder.fit(df_test[col])
    encoded = label_encoder.transform(df_test[col])
    df_test[col] = encoded
    print(enc.classes_)
    print(enc.transform(enc.classes_))
# Out:
# ['France' 'Germany' 'Spain']
# [0 1 2]
# ['Female' 'Male']
# [0 1]

# %%
# from sklearn.preprocessing import PowerTransformer

# scaler = PowerTransformer()
# df_test_scaled = scaler.fit_transform(df_test)
# df_test_scaled_df = pd.DataFrame(df_test_scaled, index=df_test.index, columns=df_test.columns)
# df_test_scaled_df.head()
# Out:
#    CreditScore  Geography    Gender       Age    Tenure   Balance  \
# 0    -0.881630  -0.849873 -1.135026 -2.245523 -1.059272 -0.914825
# 1     0.321163  -0.849873 -1.135026  0.957796 -1.059272 -0.914825
# 2    -0.016593  -0.849873 -1.135026 -0.376221  0.733772 -0.914825
# 3     0.296069  -0.849873  0.881037 -0.116594  1.050431 -0.914825
# 4     1.193988   0.892936  0.881037  0.125804  1.657915  1.095706
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0       0.872972  -1.746219        1.009580         0.966714
# 1      -1.045343   0.572666       -0.990511        -0.788052
# 2       0.872972   0.572666       -0.990511         0.529614
# 3      -1.045343   0.572666       -0.990511         0.035066
# 4      -1.045343   0.572666       -0.990511         0.540482

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_test_scaled = scaler.fit_transform(df_test)
df_test_scaled_df = pd.DataFrame(df_test_scaled, index=df_test.index, columns=df_test.columns)
df_test_scaled_df.head()
# Out:
#    CreditScore  Geography    Gender       Age    Tenure   Balance  \
# 0    -0.878176  -0.789204 -1.135026 -1.706504 -1.067887 -0.881274
# 1     0.329567  -0.789204 -1.135026  0.888990 -1.067887 -0.881274
# 2    -0.006609  -0.789204 -1.135026 -0.465181  0.713922 -0.881274
# 3     0.304665  -0.789204  0.881037 -0.239486  1.070284 -0.881274
# 4     1.188684   0.437823  0.881037 -0.013791  1.783008  1.050038
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0       0.820030  -1.746219        1.009580         0.967874
# 1      -1.015806   0.572666       -0.990511        -0.790939
# 2       0.820030   0.572666       -0.990511         0.528413
# 3      -1.015806   0.572666       -0.990511         0.032150
# 4      -1.015806   0.572666       -0.990511         0.539331

# %%
test_result = rfr.predict(df_test_scaled_df)

# %%
df_result = pd.DataFrame({
    'id': id,
    'Exited': test_result,
})

# %%
df_result.to_csv('../result/submission_rfr2.csv', index=False)
